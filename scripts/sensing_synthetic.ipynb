# %% [markdown]
# # Why doesn't L1 error decay with number of measurements?
#
# - Maybe measurement error exceeds the tolerance sometimes. This means that the error will likely increase the estimated influence of the low influence examples. Try dual optimization or investigate residual tolerance and algorithms.
# - Maybe measurement matrix has high coherence or bad restricted isometry bounds. This doesn't imply bad recovery though. Try Gaussian matrices.
# - Maybe the ground truth vector is not sparse enough. Try a simpler ground truth with exact sparsity.

# %% [markdown]
# ### Variables
# - sparsity of ground truth vector ($s$-sparse, low sparsity defect with long tail or no long tail)
# - measurement matrix (Gaussian, bounded Gaussian < 1, random subset, random binary, uniform)
# - measurement noise
# - optimization algorithm (and residual tolerance for QCBP)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
from __future__ import unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from scipy.stats import pearsonr

import IPython

sns.set(color_codes=True)
plt.style.use('seaborn')

import cvxpy
from tqdm import tqdm

# %%
def generate_only_once(func):
    cache = {}
    def wrapper(*args, **kwargs):
        key = tuple(args) + tuple(kwargs.items())
        if key not in cache:
            cache[key] = func(*args, **kwargs)
        return cache[key]
    
    return wrapper

# %%
def truncate_x(values, truncate):
    n = len(values)
    values[np.random.choice(np.arange(n), size=(truncate - n), replace=False)] = 0
    return values

@generate_only_once
def generate_uniform_x(n, truncate=None):
    truncate = n if truncate is None else truncate
    return truncate_x(np.random.uniform(-1, 1, size=(n,)), truncate)

@generate_only_once
def generate_gaussian_x(n, truncate=None, sigma=1):
    truncate = n if truncate is None else truncate
    return truncate_x(np.random.normal(0, sigma, size=(n,)), truncate)

@generate_only_once
def generate_exponential_x(n, truncate=None, scale=1, power=2):
    truncate = n if truncate is None else truncate
    return truncate_x(np.random.exponential(scale, size=(n,)) ** power, truncate)

def sparsity_defect(x_gt, ax=None, measurement_samples=20):
    n = len(x_gt)
    
    # Try using different numbers of measurements
    measurements = np.arange(n, 0, -max(n // measurement_samples, 1))
    sparsity_defect = np.zeros(len(measurements))
    
    for i, M in enumerate(measurements):
        s = M // 2
        order = np.argsort(np.abs(x_gt))
        sparsity_defect[i] = np.sum(np.abs(x_gt[order[:-s]]))
    
    if ax is None:
        ax = plt.figure(figsize=(16, 6)).gca()
    
    ax.plot(measurements, sparsity_defect, marker='o')
    ax.set_title("Sparsity defect for s = measurements/2")
    ax.set_xlabel('measurements')
    ax.set_ylabel('Sparsity defect')

# %%
@generate_only_once
def generate_uniform_A(n, m):
    return np.random.uniform(0, 1, size=(m, n))

@generate_only_once
def generate_gaussian_A(n, m, sigma=1):
    return np.random.normal(0, sigma, size=(m, n))

@generate_only_once
def generate_bounded_gaussian_A(n, m, sigma=1):
    return np.minimum(1.0, np.random.normal(0, sigma, size=(m, n)))

@generate_only_once
def generate_random_binary_A(n, m, p=0.5):
    return np.random.binomial(1, 0.5, (m, n)) # 0/1, not -1/1

@generate_only_once
def generate_random_subset_A(n, m, k=10):
    A = np.zeros((m, n))
    for i in range(m):
        A[i, np.random.choice(np.arange(n), size=k, replace=False)] = 1
    return A

# %%
def simulate_exact(A, x_gt):
    return np.dot(A, x_gt)

def simulate_uniform(A, x_gt, scale=1e-2):
    return np.dot(A, x_gt) + np.random.uniform(-scale, scale, size=(A.shape[0],))

def simulate_gaussian(A, x_gt, sigma=1e-3):
    return np.dot(A, x_gt) + np.random.normal(0, sigma, size=(A.shape[0],))

def simulate_gaussian_zero_gap(A, x_gt, sigma=1e-3, gap=1e-4):
    noise = np.random.normal(0, sigma, size=(A.shape[0],))
    noise[noise > 0] += 2 * gap
    noise -= gap
    return np.dot(A, x_gt) + noise

# %%
def basis_pursuit(A, y):
    x = cvxpy.Variable(A.shape[1])
    objective = cvxpy.Minimize(cvxpy.sum_entries(cvxpy.abs(x)))
    constraints = [ A * x == y ]
    problem = cvxpy.Problem(objective, constraints)
    problem.solve()
    if problem.status == 'optimal':
        return np.array(x.value).reshape(-1)
    else:
        return None

def qc_basis_pursuit(A, y, eta=1e-3):
    x = cvxpy.Variable(A.shape[1])
    objective = cvxpy.Minimize(cvxpy.sum_entries(cvxpy.abs(x)))
    constraints = [ cvxpy.norm(A * x - y) < eta ]
    problem = cvxpy.Problem(objective, constraints)
    problem.solve()
    if problem.status == 'optimal':
        return np.array(x.value).reshape(-1)
    else:
        return None

# %%
def error_against_measurements(A, x_gt, y,
    x_desc, A_desc, y_desc, alg_desc,
    ax=None,
    measurement_samples=20,
    sparse_recovery_alg=basis_pursuit, sparse_recovery_args={}):
    
    exp_desc = "n={}, x={}, A={}, y={}, alg={}".format(
        len(x_gt), x_desc, A_desc, y_desc, alg_desc)
    
    # Try using different numbers of measurements
    m = A.shape[0]
    measurements = np.arange(m, 0, -max(m // measurement_samples, 1))
    metrics = [
        ("L1", lambda d: np.sum(np.abs(d))),
        ("L2", lambda d: np.sqrt(np.sum(d ** 2))),
        ("Linf", lambda d: np.max(np.abs(d))),
    ]
    
    errors = np.zeros((len(measurements), len(metrics)))
    t = tqdm(enumerate(measurements))
    for i, M in t:
        t.set_description("{} measurements for {}".format(M, exp_desc))
        x = sparse_recovery_alg(A[:M, :], y[:M], **sparse_recovery_args)
        if x is not None:
            errors[i, :] = [ metric_f(x - x_gt) for name, metric_f in metrics ]
        else:
            errors[i, :] = np.nan
    
    if ax is None:
        ax = plt.figure(figsize=(16, 6)).gca()
    
    for i, metric in enumerate(metrics):
        ax.plot(measurements, errors[:, i], marker='o', label=metric[0])

    ax.set_title("Sparse recovery, {}".format(exp_desc))
    ax.set_xlabel('measurements')
    ax.set_ylabel('error')
    ax.legend()

# %%
def experiment(config, ax=None):
    n = config['n']
    m = config['m']
    measurement_samples = config.get('measurement_samples', 20)
    
    x_desc = ''
    if config['x']['truncate'] is not None:
        x_desc = '{}-sparse '.format(config['x']['truncate'])
    if config['x']['type'] == 'uniform':
        x_gt = generate_uniform_x(n, truncate=config['x']['truncate'])
        x_desc += "uniform"
    elif config['x']['type'] == 'gaussian':
        x_gt = generate_gaussian_x(n, truncate=config['x']['truncate'])
        x_desc += "gaussian"
    elif config['x']['type'] == 'exponential':
        scale, power = config['x']['scale'], config['x']['power']
        x_gt = generate_exponential_x(n, truncate=config['x']['truncate'], scale=scale, power=power)
        x_desc += "exp({})^{}".format(scale, power)
    
    A_desc = config['A']['type']
    if config['A']['type'] == 'uniform':
        A = generate_uniform_A(n, m)
    elif config['A']['type'] == 'gaussian':
        A = generate_gaussian_A(n, m)
    elif config['A']['type'] == 'bounded-gaussian':
        A = generate_bounded_gaussian_A(n, m)
    elif config['A']['type'] == 'binary':
        A = generate_random_binary_A(n, m)
    elif config['A']['type'] == 'subset':
        k = config['A']['k']
        A = generate_random_subset_A(n, m, k)
        A_desc = '{}-subset'.format(k)
        
    y_desc = config['y']['type']
    if config['y']['type'] == 'exact':
        y = simulate_exact(A, x_gt)
    elif config['y']['type'] == 'uniform':
        scale = config['y']['scale']
        y = simulate_uniform(A, x_gt, scale)
        y_desc += '({})'.format(scale)
    elif config['y']['type'] == 'gaussian':
        sigma = config['y']['sigma']
        y = simulate_gaussian(A, x_gt, sigma)
        y_desc += '({})'.format(sigma)
    elif config['y']['type'] == 'gaussian-gap':
        sigma = config['y']['sigma']
        gap = config['y']['gap']
        y = simulate_gaussian_zero_gap(A, x_gt, sigma, gap)
        y_desc += '({}, {})'.format(sigma, gap)
        
    alg_desc = config['alg']['type']
    if config['alg']['type'] == 'bp':
        alg = basis_pursuit
        alg_args = {}
    elif config['alg']['type'] == 'qcbp':
        eta = config['alg']['eta']
        alg = qc_basis_pursuit
        alg_args = { 'eta': eta }
        alg_desc += '({})'.format(eta)
    
    error_against_measurements(A, x_gt, y, x_desc, A_desc, y_desc, alg_desc, ax=ax,
        measurement_samples=measurement_samples,
        sparse_recovery_alg=alg, sparse_recovery_args=alg_args)

# %%
def experiment_grid(base_config, updates):
    fig, axs = plt.subplots(len(updates), 1, figsize=(16, 6 * len(updates)), sharex=True)
    axs = axs if len(updates) > 1 else [axs]
    for i, ax in enumerate(axs):
        config = base_config.copy()
        config.update(updates[i])
        experiment(config, ax)

# %% [markdown]
# ## What kind of vectors are we looking at?

# %%
sparsity_defect(generate_uniform_x(100))

# %%
sparsity_defect(generate_uniform_x(100, truncate=10))

# %%
sparsity_defect(generate_gaussian_x(100))

# %%
sparsity_defect(generate_gaussian_x(100, truncate=10))

# %%
sparsity_defect(generate_exponential_x(100, scale=1, power=5))

# %% [markdown]
# So the low-sparsity-defect ground-truth generated by raising an exponential distribution to some power most closely fits the sparsity defect curve of our actual influence vector.

# %% [markdown]
# ## Sanity check: $s$-sparse ground truth

# %%
experiment({
    'n': 100, 'm': 50,
    'x': { 'type': 'uniform', 'truncate': 10 },
    'A': { 'type': 'gaussian' },
    'y': { 'type': 'exact' },
    'alg': { 'type': 'bp' },
})
# Out:
# 2 measurements for n=100, x=10-sparse uniform, A=gaussian, y=exact, alg=bp: : 25it [00:00, 109.22it/s]

# %% [markdown]
# Why is there no exact recovery at $m = 2s = 20$?

# %%
experiment_grid({
    'n': 100, 'm': 50,
    'x': { 'type': 'uniform', 'truncate': 10 },
    'A': { 'type': 'gaussian' },
    'y': { 'type': 'exact' },
    'alg': { 'type': 'bp' },
}, [
    { 'alg': { 'type': 'qcbp', 'eta': 1e-3 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e-2 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e-1 } },
])
# Out:
# 2 measurements for n=100, x=10-sparse uniform, A=gaussian, y=exact, alg=qcbp(0.001): : 25it [00:00, 86.10it/s]
# 2 measurements for n=100, x=10-sparse uniform, A=gaussian, y=exact, alg=qcbp(0.01): : 25it [00:00, 91.95it/s]
# 2 measurements for n=100, x=10-sparse uniform, A=gaussian, y=exact, alg=qcbp(0.1): : 25it [00:00, 89.25it/s]

# %% [markdown]
# BP and QCBP are both equally good are recovering an actual sparse vector with a Gaussian matrix. Tolerance for QCBP also doesn't really matter.

# %% [markdown]
# ## Less-sparse ground truths

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'A': { 'type': 'gaussian' },
    'y': { 'type': 'exact' },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'x': { 'type': 'gaussian', 'truncate': 10 } },
    { 'x': { 'type': 'gaussian', 'truncate': 20 } },
    { 'x': { 'type': 'gaussian', 'truncate': 30 } },
    { 'x': { 'type': 'gaussian', 'truncate': None } },
])
# Out:
# 1 measurements for n=100, x=10-sparse gaussian, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 57.15it/s]
# 1 measurements for n=100, x=20-sparse gaussian, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 56.77it/s]
# 1 measurements for n=100, x=30-sparse gaussian, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 58.45it/s]
# 1 measurements for n=100, x=gaussian, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 62.86it/s]

# %% [markdown]
# Once we use a Gaussian vector, which is not sparse, recovery becomes much tougher.

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'A': { 'type': 'gaussian' },
    'y': { 'type': 'exact' },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'x': { 'type': 'exponential', 'truncate': 20, 'scale': 1, 'power': 3 } },
    { 'x': { 'type': 'exponential', 'truncate': 20, 'scale': 1, 'power': 5 } },
    { 'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 3 } },
    { 'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 } },
])
# Out:
# 1 measurements for n=100, x=20-sparse exp(1)^3, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 54.38it/s]
# 1 measurements for n=100, x=20-sparse exp(1)^5, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 62.60it/s]
# 1 measurements for n=100, x=exp(1)^3, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 60.28it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 59.56it/s]

# %% [markdown]
# Low-sparsity-defect truncated vectors do much better.

# %% [markdown]
# ## Measurement noise

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'A': { 'type': 'gaussian' },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'y': { 'type': 'exact' }, 'alg': { 'type': 'bp' } },
    { 'y': { 'type': 'gaussian', 'sigma': 1 }, 'alg': { 'type': 'bp' } },
    { 'y': { 'type': 'exact' } },
    { 'y': { 'type': 'gaussian', 'sigma': 1 }, },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=exact, alg=bp: : 99it [00:01, 74.30it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=bp: : 99it [00:01, 74.88it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 55.23it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 52.97it/s]

# %% [markdown]
# Noise has no effect on low-sparsity-defect vector recovery?

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'A': { 'type': 'gaussian' },
    'y': { 'type': 'gaussian', 'sigma': 1 },
}, [
    { 'alg': { 'type': 'qcbp', 'eta': 1e-1 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e0 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e1 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e2 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e3 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e4 } },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 52.19it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(1.0): : 99it [00:01, 57.20it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(10.0): : 99it [00:01, 51.57it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(100.0): : 99it [00:01, 59.94it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(1000.0): : 99it [00:01, 68.64it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(10000.0): : 99it [00:01, 81.97it/s]

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'A': { 'type': 'gaussian' },
    'y': { 'type': 'gaussian', 'sigma': 100 },
}, [
    { 'alg': { 'type': 'qcbp', 'eta': 1e-1 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e0 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e1 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e2 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e3 } },
    { 'alg': { 'type': 'qcbp', 'eta': 1e4 } },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(0.1): : 99it [00:01, 62.05it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(1.0): : 99it [00:01, 63.21it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(10.0): : 99it [00:01, 61.74it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(100.0): : 99it [00:01, 62.86it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(1000.0): : 99it [00:01, 72.71it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(10000.0): : 99it [00:01, 85.26it/s]

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'A': { 'type': 'gaussian' },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'y': { 'type': 'exact' } },
    { 'y': { 'type': 'gaussian', 'sigma': 1 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 10 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 100 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 1000 }, },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=exact, alg=qcbp(0.1): : 99it [00:01, 58.71it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 57.35it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(10), alg=qcbp(0.1): : 99it [00:01, 59.32it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(0.1): : 99it [00:01, 61.36it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1000), alg=qcbp(0.1): : 99it [00:01, 67.13it/s]

# %% [markdown]
# Noise only affects measurement if its magnitude is sufficiently large. We also finally get the L1-error increasing behavior! There's an threshold for when the system is "overdetermined", which drops as noise increases. This makes sense because QCBP is effectively defining confidence intervals.

# %%
np.linalg.svd(generate_random_subset_A(100, 99, k=10))
# Out:
# (array([[-0.09618208,  0.05488708, -0.04327776, ...,  0.01609619,
#           0.17878477,  0.13915147],
#         [-0.09625582,  0.04691139, -0.20314847, ...,  0.01098036,
#          -0.04503455,  0.05814626],
#         [-0.10415119,  0.17941118, -0.01358397, ..., -0.15623796,
#           0.17833219, -0.07539147],
#         ...,
#         [-0.10413041, -0.18103111, -0.03753791, ..., -0.03757744,
#           0.03475764, -0.00173898],
#         [-0.10371646,  0.02894192, -0.16445549, ..., -0.05145234,
#           0.16017622, -0.12937968],
#         [-0.10756398,  0.22192511,  0.11407038, ...,  0.03626548,
#          -0.21179477,  0.08938731]]),
#  array([10.48467817,  5.76540584,  5.69858755,  5.55107806,  5.41723826,
#          5.3902858 ,  5.20058648,  5.19890898,  5.06146571,  4.92610868,
#          4.88700721,  4.80516223,  4.69080878,  4.63057746,  4.52833182,
#          4.49763476,  4.43758587,  4.33008418,  4.25625007,  4.24789731,
#          4.19682517,  4.01714715,  3.98274476,  3.93755671,  3.83287501,
#          3.79999682,  3.74648566,  3.71507368,  3.59906492,  3.58043999,
#          3.4883895 ,  3.45012252,  3.34581616,  3.28016395,  3.23327272,
#          3.21439781,  3.10550615,  3.02661893,  2.99932785,  2.9483501 ,
#          2.9147334 ,  2.84633509,  2.81605259,  2.74087523,  2.675414  ,
#          2.66388321,  2.58057346,  2.5377204 ,  2.52695595,  2.43704847,
#          2.3800368 ,  2.34436705,  2.32424413,  2.29830039,  2.16151597,
#          2.12847554,  2.09994816,  2.0826383 ,  2.02778488,  1.9231486 ,
#          1.85639789,  1.8056577 ,  1.74015391,  1.6599566 ,  1.59933555,
#          1.58016493,  1.51855445,  1.48928807,  1.43706209,  1.38518838,
#          1.34084979,  1.29638225,  1.27904461,  1.19528508,  1.17508155,
#          1.12438664,  1.08495711,  1.02760395,  1.00675404,  0.96425231,
#          0.91600574,  0.85975717,  0.78670996,  0.73943525,  0.70454384,
#          0.67463548,  0.6336932 ,  0.56990984,  0.56554889,  0.47188075,
#          0.41698602,  0.36306623,  0.31325228,  0.24385369,  0.20882977,
#          0.17584742,  0.11014917,  0.06953398,  0.046667  ]),
#  array([[-0.08538769, -0.05327612, -0.1482346 , ..., -0.0457115 ,
#          -0.04638463, -0.12197858],
#         [-0.08989511, -0.07686027, -0.19547121, ...,  0.02375426,
#          -0.02586353, -0.04363735],
#         [-0.08443435,  0.01798166,  0.14084395, ...,  0.03643095,
#           0.00461005,  0.18511022],
#         ...,
#         [-0.11729561, -0.09707811,  0.05065142, ..., -0.04934781,
#          -0.29516394, -0.01316743],
#         [-0.07565914, -0.09029845, -0.05723021, ..., -0.15523116,
#           0.09012047, -0.04216734],
#         [-0.06127727, -0.17052503,  0.08868642, ..., -0.03724589,
#          -0.11779845,  0.11933375]]))

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'A': { 'type': 'subset', 'k': 10 },
    'alg': { 'type': 'bp' },
}, [
    { 'y': { 'type': 'exact' } },
    { 'y': { 'type': 'gaussian', 'sigma': 1 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 10 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 100 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 1000 }, },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=exact, alg=bp: : 99it [00:00, 154.62it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(1), alg=bp: : 99it [00:00, 160.38it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(10), alg=bp: : 99it [00:00, 163.40it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(100), alg=bp: : 99it [00:00, 171.09it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(1000), alg=bp: : 99it [00:00, 170.14it/s]

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'A': { 'type': 'subset', 'k': 10 },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'y': { 'type': 'exact' } },
    { 'y': { 'type': 'gaussian', 'sigma': 1 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 10 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 100 }, },
    { 'y': { 'type': 'gaussian', 'sigma': 1000 }, },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=exact, alg=qcbp(0.1): : 99it [00:00, 124.64it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(1), alg=qcbp(0.1): : 99it [00:00, 120.24it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(10), alg=qcbp(0.1): : 99it [00:00, 121.18it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(100), alg=qcbp(0.1): : 99it [00:00, 131.19it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(1000), alg=qcbp(0.1): : 99it [00:00, 127.92it/s]

# %% [markdown]
# Random-subset matrices fare terribly in the noisy setting, and are not even able to recover the vectors.

# %% [markdown]
# ## Measurement matrices

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'y': { 'type': 'gaussian', 'sigma': 100 },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'A': { 'type': 'uniform' }, },
    { 'A': { 'type': 'gaussian' }, },
    { 'A': { 'type': 'bounded-gaussian' }, },
    { 'A': { 'type': 'binary' }, },
    { 'A': { 'type': 'subset', 'k': 5 }, },
    { 'A': { 'type': 'subset', 'k': 10 }, },
    { 'A': { 'type': 'subset', 'k': 15 }, },
    { 'A': { 'type': 'subset', 'k': 25 }, },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=uniform, y=gaussian(100), alg=qcbp(0.1): : 99it [00:01, 62.32it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(100), alg=qcbp(0.1): : 99it [00:01, 63.64it/s]
# 1 measurements for n=100, x=exp(1)^5, A=bounded-gaussian, y=gaussian(100), alg=qcbp(0.1): : 99it [00:01, 61.60it/s]
# 1 measurements for n=100, x=exp(1)^5, A=binary, y=gaussian(100), alg=qcbp(0.1): : 99it [00:01, 86.46it/s]
# 1 measurements for n=100, x=exp(1)^5, A=5-subset, y=gaussian(100), alg=qcbp(0.1): : 99it [00:00, 146.66it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(100), alg=qcbp(0.1): : 99it [00:00, 130.86it/s]
# 1 measurements for n=100, x=exp(1)^5, A=15-subset, y=gaussian(100), alg=qcbp(0.1): : 99it [00:00, 120.61it/s]
# 1 measurements for n=100, x=exp(1)^5, A=25-subset, y=gaussian(100), alg=qcbp(0.1): : 99it [00:00, 108.04it/s]

# %% [markdown]
# Literally any other type of matrix would be better, even random binary matrices.

# %%
experiment_grid({
    'n': 100, 'm': 99,
    'measurement_samples': 50,
    'x': { 'type': 'exponential', 'truncate': None, 'scale': 1, 'power': 5 },
    'y': { 'type': 'gaussian', 'sigma': 1 },
    'alg': { 'type': 'qcbp', 'eta': 1e-1 },
}, [
    { 'A': { 'type': 'uniform' }, },
    { 'A': { 'type': 'gaussian' }, },
    { 'A': { 'type': 'bounded-gaussian' }, },
    { 'A': { 'type': 'binary' }, },
    { 'A': { 'type': 'subset', 'k': 5 }, },
    { 'A': { 'type': 'subset', 'k': 10 }, },
    { 'A': { 'type': 'subset', 'k': 15 }, },
    { 'A': { 'type': 'subset', 'k': 25 }, },
])
# Out:
# 1 measurements for n=100, x=exp(1)^5, A=uniform, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 53.55it/s]
# 1 measurements for n=100, x=exp(1)^5, A=gaussian, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 57.72it/s]
# 1 measurements for n=100, x=exp(1)^5, A=bounded-gaussian, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 58.63it/s]
# 1 measurements for n=100, x=exp(1)^5, A=binary, y=gaussian(1), alg=qcbp(0.1): : 99it [00:01, 78.48it/s]
# 1 measurements for n=100, x=exp(1)^5, A=5-subset, y=gaussian(1), alg=qcbp(0.1): : 99it [00:00, 131.23it/s]
# 1 measurements for n=100, x=exp(1)^5, A=10-subset, y=gaussian(1), alg=qcbp(0.1): : 99it [00:00, 120.65it/s]
# 1 measurements for n=100, x=exp(1)^5, A=15-subset, y=gaussian(1), alg=qcbp(0.1): : 99it [00:00, 109.92it/s]
# 1 measurements for n=100, x=exp(1)^5, A=25-subset, y=gaussian(1), alg=qcbp(0.1): : 99it [00:00, 102.00it/s]
